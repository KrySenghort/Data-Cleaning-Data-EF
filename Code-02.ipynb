# %% [markdown]
# ### Dataset 01 : Cambodia Total Trade Statistics of Last 5 Years

# %%
import requests
import pandas as pd

url = "https://data.mef.gov.kh/api/v1/public-datasets/pd_66bdb35549eb6c00013c1350/json?page=1&page_size=10"
response = requests.get(url)
data01 = response.json()

# Extract the 'items' list
items = data01['items']
df = pd.DataFrame(items)
df = df.drop(columns=['row_number'])
df.head()
# Out:
#      year       export       import      balance       volume
# 0  1970.0  14748738.00  20171813.00 -5423073.000  34920551.00
# 1  1970.0  18342259.00  19100028.00  -757768.000  37442285.00
# 2  1970.0  19308910.00  28702889.66 -9393979.662  48011799.65
# 3  1970.0  19308910.00  28702889.66 -9393979.662  48011799.65
# 4  1970.0  22644989.33  24183042.79 -1538053.465  46828032.13

# %%
df.rename(columns={'total trade statistics of last 5 years' : 'Year'}, inplace=True)
df
# Out:
#      year       export       import      balance       volume
# 0  1970.0  14748738.00  20171813.00 -5423073.000  34920551.00
# 1  1970.0  18342259.00  19100028.00  -757768.000  37442285.00
# 2  1970.0  19308910.00  28702889.66 -9393979.662  48011799.65
# 3  1970.0  19308910.00  28702889.66 -9393979.662  48011799.65
# 4  1970.0  22644989.33  24183042.79 -1538053.465  46828032.13

# %%
df['Year'] = df['year'].astype('Int64')
df
# Out:
#      year       export       import      balance       volume  Year
# 0  1970.0  14748738.00  20171813.00 -5423073.000  34920551.00  1970
# 1  1970.0  18342259.00  19100028.00  -757768.000  37442285.00  1970
# 2  1970.0  19308910.00  28702889.66 -9393979.662  48011799.65  1970
# 3  1970.0  19308910.00  28702889.66 -9393979.662  48011799.65  1970
# 4  1970.0  22644989.33  24183042.79 -1538053.465  46828032.13  1970

# %%
df = df.drop(columns=['year'])
df
# Out:
#         export       import      balance       volume  Year
# 0  14748738.00  20171813.00 -5423073.000  34920551.00  1970
# 1  18342259.00  19100028.00  -757768.000  37442285.00  1970
# 2  19308910.00  28702889.66 -9393979.662  48011799.65  1970
# 3  19308910.00  28702889.66 -9393979.662  48011799.65  1970
# 4  22644989.33  24183042.79 -1538053.465  46828032.13  1970

# %%
df['Year'].first_valid_index
df
# Out:
#         export       import      balance       volume  Year
# 0  14748738.00  20171813.00 -5423073.000  34920551.00  1970
# 1  18342259.00  19100028.00  -757768.000  37442285.00  1970
# 2  19308910.00  28702889.66 -9393979.662  48011799.65  1970
# 3  19308910.00  28702889.66 -9393979.662  48011799.65  1970
# 4  22644989.33  24183042.79 -1538053.465  46828032.13  1970

# %%
df.dtypes
# Out:
# year       float64
# export     float64
# import     float64
# balance    float64
# volume     float64
# dtype: object

# %%
df.dtypes
# Out:
# Year         int32
# export     float64
# import     float64
# balance    float64
# volume     float64
# dtype: object

# %%
df.to_csv('06-Cambodia Total Trade Statistics of Last 5 Years.csv',index=False)
print("Data saved to 'Cambodia Total Trade Statistics of Last 5 Years.csv'")
# Out:
# Data saved to 'Cambodia Total Trade Statistics of Last 5 Years.csv'

# %% [markdown]
# ### Dataset 07: Cambodia's Economic Overview and Future Outlook (2015-2029)

# %%
import requests

url = "https://data.mef.gov.kh/api/v1/public-datasets/pd_681bb9e6dbc953000126f5c4/json?page=1&page_size=100"
response = requests.get(url)
data02 = response.json()

# Extract the 'items' list
items = data02['items']
df = pd.DataFrame(items)
df = df.drop(columns=['row_number'])
df.head()
# Out:
#     country                       subject descriptor  \
# 0  Cambodia  Gross domestic product, constant prices
# 1  Cambodia  Gross domestic product, constant prices
# 2  Cambodia   Gross domestic product, current prices
# 3  Cambodia   Gross domestic product, current prices
# 4  Cambodia   Gross domestic product, current prices
#
#                                             units     scale      2015  \
# 0                               National currency  Billions  95406.13
# 1                                  Percent change     Units      7.21
# 2                               National currency  Billions  98334.48
# 3                                    U.S. dollars  Billions     24.22
# 4  Purchasing power parity; international dollars  Billions     67.74
#
#         2016       2017       2018       2019       2020  ...       2022  \
# 0  102948.46  111261.59  121026.15  130631.94  125987.03  ...  136508.08
# 1       7.91       8.08       8.78       7.94      -3.56  ...       5.10
# ...

# %%
df = df.transpose()
import pandas as pd

# Assume df is your DataFrame

# Identify columns that are years (they're numeric strings or integers)
year_columns = [col for col in df.columns if str(col).isdigit()]

# Melt the DataFrame to long format
df_long = pd.melt(
    df,
    id_vars=[col for col in df.columns if col not in year_columns],  # keep text columns
    value_vars=year_columns,                                         # melt only year columns
    var_name='Year',                                                 # new column for years
    value_name='Value'                                               # new column for data values
)

# Convert Year to integer if needed
df_long['Year'] = df_long['Year'].astype(int)

# Display result
df_long.head()
# Out:
#     country                       subject descriptor  \
# 0  Cambodia  Gross domestic product, constant prices
# 1  Cambodia  Gross domestic product, constant prices
# 2  Cambodia   Gross domestic product, current prices
# 3  Cambodia   Gross domestic product, current prices
# 4  Cambodia   Gross domestic product, current prices
#
#                                             units     scale  \
# 0                               National currency  Billions
# 1                                  Percent change     Units
# 2                               National currency  Billions
# 3                                    U.S. dollars  Billions
# 4  Purchasing power parity; international dollars  Billions
#
#   estimates start after                      country/series-specific notes  \
# 0                2022.0  Source: National Statistics Office Latest actu...
# 1                2022.0  See notes for:  Gross domestic product, consta...
# ...

# %%
# Convert to integer year safely
df_long['estimates start after'] = df_long['estimates start after'].astype(float).astype('Int64')
df_long['Year'] = df_long['Year'].astype(int)
df_long
# Out:
#       country                                 subject descriptor  \
# 0    Cambodia            Gross domestic product, constant prices
# 1    Cambodia            Gross domestic product, constant prices
# 2    Cambodia             Gross domestic product, current prices
# 3    Cambodia             Gross domestic product, current prices
# 4    Cambodia             Gross domestic product, current prices
# ..        ...                                                ...
# 550  Cambodia                      General government gross debt
# 551  Cambodia                      General government gross debt
# 552  Cambodia  Gross domestic product corresponding to fiscal...
# 553  Cambodia                            Current account balance
# 554  Cambodia                            Current account balance
#
#                                               units     scale  \
# 0                                 National currency  Billions
# ...

# %%
# Reorder and rename columns for clarity
df_long = df_long[[
    'Year',
    'estimates start after',
    'country',
    'subject descriptor',
    'units',
    'Value',
    'scale',
    'country/series-specific notes'
]]
df_long
# Out:
#      Year  estimates start after   country  \
# 0    2015                   2022  Cambodia
# 1    2015                   2022  Cambodia
# 2    2015                   2022  Cambodia
# 3    2015                   2022  Cambodia
# 4    2015                   2022  Cambodia
# ..    ...                    ...       ...
# 550  2029                   2022  Cambodia
# 551  2029                   2022  Cambodia
# 552  2029                   2022  Cambodia
# 553  2029                   2022  Cambodia
# 554  2029                   2022  Cambodia
#
#                                     subject descriptor  \
# 0              Gross domestic product, constant prices
# 1              Gross domestic product, constant prices
# 2               Gross domestic product, current prices
# 3               Gross domestic product, current prices
# 4               Gross domestic product, current prices
# ..                                                 ...
# ...

# %%
df_long.to_csv("07-Cambodia's Economic Overview and Future Outlook (2015-2029).csv", index=False)

# %% [markdown]
# ### Dataset 08: Cambodia's Macroeconomic Outlook: Recovery and Projections (2019–2026)

# %%
import requests
import pandas as pd

url = "https://data.mef.gov.kh/api/v1/public-datasets/pd_681c1151dbc953000126f5ca/json?page=1&page_size=10"
response = requests.get(url)
data02 = response.json()

# Extract the 'items' list
items = data02['items']
df = pd.DataFrame(items)
df = df.drop(columns=['row_number'])
df.head()
# Out:
#     no                                    sector  2019  2020  2021  2022  \
# 0  1.0              National Accounts and Prices   NaN   NaN   NaN   NaN
# 1  1.1  GDP at constant market prices (% change)   7.1  -3.1   3.0   5.2
# 2  1.2                               Agriculture  -0.5   0.6   1.2   0.7
# 3  1.3                                  Industry  11.3  -1.4   9.4   8.3
# 4  1.4                                  Services   6.2  -6.3  -2.7   3.5
#
#    2023e  2024p  2025p  2026p
# 0    NaN    NaN    NaN    NaN
# 1    5.4    5.8    6.1    6.4
# 2    1.4    1.4    1.4    1.5
# 3    7.4    7.7    7.7    7.7
# 4    6.0    6.3    6.3    6.4

# %%
import pandas as pd

# Step 1: Melt the DataFrame to long format
df_melted = df.melt(id_vars=['no', 'sector'], 
                    var_name='year_raw', 
                    value_name='value')

# Step 2: Extract year, is_estimated, is_predicted
df_melted['is_estimated'] = df_melted['year_raw'].str.endswith('e')
df_melted['is_predicted'] = df_melted['year_raw'].str.endswith('p')
df_melted['year'] = df_melted['year_raw'].str.extract(r'(\d{4})').astype(int)

# Step 3: Final normalized structure
df_normalized = df_melted[['no', 'sector', 'year', 'value', 'is_estimated', 'is_predicted']]

# Optional: sort for readability
df_normalized = df_normalized.sort_values(['no', 'year'])
df_normalized
# Out:
#      no                              sector  year  value  is_estimated  \
# 0   1.0        National Accounts and Prices  2019    NaN         False
# 10  1.0        National Accounts and Prices  2020    NaN         False
# 20  1.0        National Accounts and Prices  2021    NaN         False
# 30  1.0        National Accounts and Prices  2022    NaN         False
# 40  1.0        National Accounts and Prices  2023    NaN          True
# ..  ...                                 ...   ...    ...           ...
# 39  2.3  Overall balance (including grants)  2022   -4.4         False
# 49  2.3  Overall balance (including grants)  2023   -5.3          True
# 59  2.3  Overall balance (including grants)  2024   -5.5         False
# 69  2.3  Overall balance (including grants)  2025   -4.4         False
# 79  2.3  Overall balance (including grants)  2026   -4.2         False
#
#     is_predicted
# 0          False
# 10         False
# 20         False
# 30         False
# 40         False
# ...

# %% [markdown]
# #### Dataset 09: Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2021

# %%
import requests
import pandas as pd

all_items = []

# Loop through all 146 pages
for page in range(1, 2):
    url = f"https://data.mef.gov.kh/api/v1/public-datasets/pd_6768c749255e6c0001248280/json?page={page}&page_size=100"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])
        all_items.extend(items)
    else:
        print(f"Failed to fetch page {page}")

# Create DataFrame from all items
df09 = pd.DataFrame(all_items)

# Drop 'row_number' column if it exists
if 'row_number' in df09.columns:
    df09 = df09.drop(columns=['row_number'])

df09
# Out:
#    ទេសចរណ៍ទិញបណ្ណ  ចំនួនភ្ញៀវ  ចំណូល(ដុល្លារ)
# 0            មករា        62.0           930.0
# 1          កុម្ភៈ        70.0          1050.0
# 2            មីនា        26.0           390.0
# 3            មេសា         1.0            15.0
# 4            ឧសភា        23.0           345.0
# 5          មិថុនា        27.0           405.0
# 6          កក្កដា        36.0           540.0
# 7            សីហា         0.0             0.0
# 8           កញ្ញា         6.0            90.0
# 9            តុលា        52.0           780.0
# 10       វិច្ឆិកា        86.0          1290.0
# 11           ធ្នូ       122.0          1830.0

# %%
df09 = df09.rename(columns={
    'ទេសចរណ៍ទិញបណ្ណ' : 'Month',
    'ចំនួនភ្ញៀវ' : 'Number of Visitors',
    'ចំណូល(ដុល្លារ)' : 'Revenue(USD)',
})
df09
# Out:
#        Month  Number of Visitors  Revenue(USD)
# 0       មករា                62.0         930.0
# 1     កុម្ភៈ                70.0        1050.0
# 2       មីនា                26.0         390.0
# 3       មេសា                 1.0          15.0
# 4       ឧសភា                23.0         345.0
# 5     មិថុនា                27.0         405.0
# 6     កក្កដា                36.0         540.0
# 7       សីហា                 0.0           0.0
# 8      កញ្ញា                 6.0          90.0
# 9       តុលា                52.0         780.0
# 10  វិច្ឆិកា                86.0        1290.0
# 11      ធ្នូ               122.0        1830.0

# %%
# Khmer to English month mapping
khmer_to_english_months = {
    'មករា': 'January',
    'កុម្ភៈ': 'February',
    'មីនា': 'March',
    'មេសា': 'April',
    'ឧសភា': 'May',
    'មិថុនា': 'June',
    'កក្កដា': 'July',
    'សីហា': 'August',
    'កញ្ញា': 'September',
    'តុលា': 'October',
    'វិច្ឆិកា': 'November',
    'ធ្នូ': 'December'
}

# Replace Khmer month names with English
df09['Month'] = df09['Month'].map(khmer_to_english_months)
df09
# Out:
#         Month  Number of Visitors  Revenue(USD)
# 0     January                62.0         930.0
# 1    February                70.0        1050.0
# 2       March                26.0         390.0
# 3       April                 1.0          15.0
# 4         May                23.0         345.0
# 5        June                27.0         405.0
# 6        July                36.0         540.0
# 7      August                 0.0           0.0
# 8   September                 6.0          90.0
# 9     October                52.0         780.0
# 10   November                86.0        1290.0
# 11   December               122.0        1830.0

# %%
# Assigned Year = 2021
year = 2021
# Create a date string and convert to datetime format
df09['Month'] = pd.to_datetime(df09['Month'] + '-' + str(year))
df09
# Out:
# C:\Users\Rog Strix\AppData\Local\Temp\ipykernel_27272\1082449380.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df09['Month'] = pd.to_datetime(df09['Month'] + '-' + str(year))
#         Month  Number of Visitors  Revenue(USD)
# 0  2021-01-01                62.0         930.0
# 1  2021-02-01                70.0        1050.0
# 2  2021-03-01                26.0         390.0
# 3  2021-04-01                 1.0          15.0
# 4  2021-05-01                23.0         345.0
# 5  2021-06-01                27.0         405.0
# 6  2021-07-01                36.0         540.0
# 7  2021-08-01                 0.0           0.0
# 8  2021-09-01                 6.0          90.0
# 9  2021-10-01                52.0         780.0
# 10 2021-11-01                86.0        1290.0
# 11 2021-12-01               122.0        1830.0

# %%
df09.to_csv('09-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2021.csv', index=False)
print("Data saved to '09-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2021.csv'")
# Out:
# Data saved to '09-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2021.csv'

# %%
import requests
import pandas as pd

all_items = []

# Loop through all 146 pages
for page in range(1, 2):
    url = f"https://data.mef.gov.kh/api/v1/public-datasets/pd_6760f11c255e6c000124823b/json?page={page}&page_size=100"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])
        all_items.extend(items)
    else:
        print(f"Failed to fetch page {page}")

# Create DataFrame from all items
df10 = pd.DataFrame(all_items)

# Drop 'row_number' column if it exists
if 'row_number' in df10.columns:
    df10 = df10.drop(columns=['row_number'])

df10 = df10.rename(columns={
    'ទេសចរណ៍ទិញបណ្ណ' : 'Month',
    'ចំនួនភ្ញៀវ' : 'Number of Visitors',
    'ចំណូល(ដុល្លារ)' : 'Revenue(USD)',
})

# Khmer to English month mapping
khmer_to_english_months = {
    'មករា': 'January',
    'កុម្ភៈ': 'February',
    'មីនា': 'March',
    'មេសា': 'April',
    'ឧសភា': 'May',
    'មិថុនា': 'June',
    'កក្កដា': 'July',
    'សីហា': 'August',
    'កញ្ញា': 'September',
    'តុលា': 'October',
    'វិច្ឆិកា': 'November',
    'ធ្នូ': 'December'
}

# Replace Khmer month names with English
df10['Month'] = df10['Month'].map(khmer_to_english_months)

# Assigned Year = 2022
year = 2022
# Create a date string and convert to datetime format
df10['Month'] = pd.to_datetime(df10['Month'] + '-' + str(year))

df10.to_csv('10-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2022.csv', index=False)
print("Data saved to '10-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2022.csv'")
df10
# Out:
# Data saved to '10-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2022.csv'
# C:\Users\Rog Strix\AppData\Local\Temp\ipykernel_27272\1074913845.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df10['Month'] = pd.to_datetime(df10['Month'] + '-' + str(year))
#         Month  Number of Visitors  Revenue(USD)
# 0  2022-01-01               115.0        1725.0
# 1  2022-02-01               157.0        2355.0
# 2  2022-03-01               189.0        2835.0
# 3  2022-04-01               229.0        3435.0
# 4  2022-05-01               189.0        2835.0
# 5  2022-06-01               187.0        2805.0
# 6  2022-07-01               457.0        6855.0
# 7  2022-08-01               659.0        9885.0
# 8  2022-09-01               363.0        5445.0
# 9  2022-10-01               621.0        9315.0
# ...

# %%
import requests
import pandas as pd

all_items = []

# Loop through all 146 pages
for page in range(1, 2):
    url = f"https://data.mef.gov.kh/api/v1/public-datasets/pd_675fea34255e6c0001248214/json?page={page}&page_size=100"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])
        all_items.extend(items)
    else:
        print(f"Failed to fetch page {page}")

# Create DataFrame from all items
df10 = pd.DataFrame(all_items)

# Drop 'row_number' column if it exists
if 'row_number' in df10.columns:
    df10 = df10.drop(columns=['row_number'])

df10 = df10.rename(columns={
    'ទេសចរណ៍ទិញបណ្ណ' : 'Month',
    'ចំនួនភ្ញៀវ' : 'Number of Visitors',
    'ចំណូល(ដុល្លារ)' : 'Revenue(USD)',
})

# Khmer to English month mapping
khmer_to_english_months = {
    'មករា': 'January',
    'កុម្ភៈ': 'February',
    'មីនា': 'March',
    'មេសា': 'April',
    'ឧសភា': 'May',
    'មិថុនា': 'June',
    'កក្កដា': 'July',
    'សីហា': 'August',
    'កញ្ញា': 'September',
    'តុលា': 'October',
    'វិច្ឆិកា': 'November',
    'ធ្នូ': 'December'
}

# Replace Khmer month names with English
df10['Month'] = df10['Month'].map(khmer_to_english_months)

# Assigned Year = 2023
year = 2023
# Create a date string and convert to datetime format
df10['Month'] = pd.to_datetime(df10['Month'] + '-' + str(year))

df10.to_csv('11-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2023.csv', index=False)
print("Data saved to '11-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2023.csv'")
df10
# Out:
# Data saved to '11-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2023.csv'
# C:\Users\Rog Strix\AppData\Local\Temp\ipykernel_27272\835394210.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df10['Month'] = pd.to_datetime(df10['Month'] + '-' + str(year))
#         Month  Number of Visitors  Revenue(USD)
# 0  2023-01-01              1612.0       24180.0
# 1  2023-02-01              1434.0       21510.0
# 2  2023-03-01              1313.0       19695.0
# 3  2023-04-01               859.0       12885.0
# 4  2023-05-01               720.0       10800.0
# 5  2023-06-01               431.0        6465.0
# 6  2023-07-01               706.0       10590.0
# 7  2023-08-01              1120.0       16800.0
# 8  2023-09-01               635.0        9525.0
# 9  2023-10-01              1104.0       16560.0
# ...

# %%
import requests
import pandas as pd

all_items = []

# Loop through all 146 pages
for page in range(1, 2):
    url = f"https://data.mef.gov.kh/api/v1/public-datasets/pd_675fe9db255e6c0001248213/json?page={page}&page_size=100"
    response = requests.get(url)
    
    if response.status_code == 200:
        data = response.json()
        items = data.get('items', [])
        all_items.extend(items)
    else:
        print(f"Failed to fetch page {page}")

# Create DataFrame from all items
df10 = pd.DataFrame(all_items)

# Drop 'row_number' column if it exists
if 'row_number' in df10.columns:
    df10 = df10.drop(columns=['row_number'])

df10 = df10.rename(columns={
    'ទេសចរណ៍ទិញបណ្ណ' : 'Month',
    'ចំនួនភ្ញៀវ' : 'Number of Visitors',
    'ចំណូល(ដុល្លារ)' : 'Revenue(USD)',
})

# Khmer to English month mapping
khmer_to_english_months = {
    'មករា': 'January',
    'កុម្ភៈ': 'February',
    'មីនា': 'March',
    'មេសា': 'April',
    'ឧសភា': 'May',
    'មិថុនា': 'June',
    'កក្កដា': 'July',
    'សីហា': 'August',
    'កញ្ញា': 'September',
    'តុលា': 'October',
    'វិច្ឆិកា': 'November',
    'ធ្នូ': 'December'
}

# Replace Khmer month names with English
df10['Month'] = df10['Month'].map(khmer_to_english_months)

# Assigned Year = 2024
year = 2024
# Create a date string and convert to datetime format
df10['Month'] = pd.to_datetime(df10['Month'] + '-' + str(year))

df10.to_csv('12-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2024.csv', index=False)
print("Data saved to '12-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2024.csv'")
df10
# Out:
# Data saved to '12-Foreign Tourism Statistics and Revenue from Koh Ker Temple of FY2024.csv'
# C:\Users\Rog Strix\AppData\Local\Temp\ipykernel_27272\324759701.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df10['Month'] = pd.to_datetime(df10['Month'] + '-' + str(year))
#         Month  Number of Visitors  Revenue(USD)
# 0  2024-01-01              2894.0       43410.0
# 1  2024-02-01              2902.0       43530.0
# 2  2024-03-01              2281.0       34215.0
# 3  2024-04-01              1090.0       16350.0
# 4  2024-05-01               960.0       14400.0
# 5  2024-06-01               701.0       10515.0
# 6  2024-07-01               993.0       14895.0
# 7  2024-08-01              1353.0       20295.0
# 8  2024-09-01               696.0       10440.0
# 9  2024-10-01              1375.0       20625.0
# ...

# %% [markdown]
# #### Dataset 10: Forest area (% of land area) - Cambodia

# %%
import requests

url = "https://data.mef.gov.kh/api/v1/public-datasets/pd_67624d2c255e6c0001248260/json?page=1&page_size=10"
response = requests.get(url)
data02 = response.json()

# Extract the 'items' list
items = data02['items']
df = pd.DataFrame(items)
df = df.drop(columns=['row_number'])
df
# Out:
#   country name country code                indicator name  indicator code  \
# 0     Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
#
#         1990       1991       1992       1993       1994       1995  ...  \
# 0  62.343021  62.216242  62.089463  61.962684  61.835905  61.709126  ...
#
#         2013       2014       2015       2016       2017       2018  \
# 0  54.066304  52.092126  50.117947  49.235951  48.353954  47.471958
#
#         2019       2020       2021       2022
# 0  46.589961  45.707965  44.825969  43.943972
#
# [1 rows x 37 columns]

# %%
# Melt the dataframe: keep only the text columns as identifiers
df_long = pd.melt(
    df,
    id_vars=['country name', 'country code', 'indicator name', 'indicator code'],
    var_name='Year',
    value_name='Value'
)

# Convert 'Year' to integer (optional, but recommended for analysis)
df_long['Year'] = df_long['Year'].astype(int)
df_long
# Out:
#    country name country code                indicator name  indicator code  \
# 0      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 1      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 2      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 3      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 4      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 5      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 6      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 7      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 8      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 9      Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# 10     Cambodia          KHM  Forest area (% of land area)  AG.LND.FRST.ZS
# ...

# %%
df_long.dtypes
# Out:
# country name       object
# country code       object
# indicator name     object
# indicator code     object
# Year                int32
# Value             float64
# dtype: object

# %%
df_long.columns.tolist()
# Out:
# ['country name',
#  'country code',
#  'indicator name',
#  'indicator code',
#  'Year',
#  'Value']

# %%
df_long = df_long[[
    'Year',
    'country code',
    'country name',
    'indicator code',
    'indicator name',
    'Value'
]]
df_long
# Out:
#     Year country code country name  indicator code  \
# 0   1990          KHM     Cambodia  AG.LND.FRST.ZS
# 1   1991          KHM     Cambodia  AG.LND.FRST.ZS
# 2   1992          KHM     Cambodia  AG.LND.FRST.ZS
# 3   1993          KHM     Cambodia  AG.LND.FRST.ZS
# 4   1994          KHM     Cambodia  AG.LND.FRST.ZS
# 5   1995          KHM     Cambodia  AG.LND.FRST.ZS
# 6   1996          KHM     Cambodia  AG.LND.FRST.ZS
# 7   1997          KHM     Cambodia  AG.LND.FRST.ZS
# 8   1998          KHM     Cambodia  AG.LND.FRST.ZS
# 9   1999          KHM     Cambodia  AG.LND.FRST.ZS
# 10  2000          KHM     Cambodia  AG.LND.FRST.ZS
# 11  2001          KHM     Cambodia  AG.LND.FRST.ZS
# 12  2002          KHM     Cambodia  AG.LND.FRST.ZS
# 13  2003          KHM     Cambodia  AG.LND.FRST.ZS
# 14  2004          KHM     Cambodia  AG.LND.FRST.ZS
# 15  2005          KHM     Cambodia  AG.LND.FRST.ZS
# 16  2006          KHM     Cambodia  AG.LND.FRST.ZS
# ...

# %%
df_long.to_csv('13-Forest area (percentage of land area) in Cambodia between 1990 to 2022.csv', index=False)

# %% [markdown]
# #### Dataset 11: Cambodia’s Gross Domestic Product (GDP) in current US dollars from 1975 to 2023

# %%
import requests

url = "https://data.mef.gov.kh/api/v1/public-datasets/pd_67612ef4255e6c0001248246/json?page=1&page_size=10"
response = requests.get(url)
data02 = response.json()

# Extract the 'items' list
items = data02['items']
df = pd.DataFrame(items)
df = df.drop(columns=['row_number'])
df
# Out:
#   country name country code     indicator name  indicator code  1960  \
# 0     Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  None
#
#           1975         1976         1977         1978         1979  ...  \
# 0  749129748.2  790357254.5  716261764.5  766642356.1  723738502.7  ...
#
#            2014          2015          2016          2017          2018  \
# 0  2.204146e+10  2.417417e+10  2.655655e+10  2.935567e+10  3.314589e+10
#
#            2019          2020          2021          2022          2023
# 0  3.668536e+10  3.481807e+10  3.679016e+10  3.999453e+10  4.233565e+10
#
# [1 rows x 54 columns]

# %%
# Melt the dataframe: keep only the text columns as identifiers
df_long = pd.melt(
    df,
    id_vars=['country name', 'country code', 'indicator name', 'indicator code'],
    var_name='Year',
    value_name='Value'
)

# Convert 'Year' to integer (optional, but recommended for analysis)
df_long['Year'] = df_long['Year'].astype(int)
df_long
# Out:
#    country name country code     indicator name  indicator code  Year  \
# 0      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1960
# 1      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1975
# 2      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1976
# 3      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1977
# 4      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1978
# 5      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1979
# 6      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1980
# 7      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1981
# 8      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1982
# 9      Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1983
# 10     Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1984
# 11     Cambodia          KHM  GDP (current US$)  NY.GDP.MKTP.CD  1985
# ...

# %%
df_long = df_long[[
    'Year',
    'country code',
    'country name',
    'indicator code',
    'indicator name',
    'Value'
]]
df_long
# Out:
#     Year country code country name  indicator code     indicator name  \
# 0   1960          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 1   1975          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 2   1976          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 3   1977          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 4   1978          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 5   1979          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 6   1980          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 7   1981          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 8   1982          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 9   1983          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 10  1984          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 11  1985          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# ...

# %%
df_long = df_long.dropna(subset=['Value'])
df_long
# Out:
#     Year country code country name  indicator code     indicator name  \
# 1   1975          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 2   1976          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 3   1977          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 4   1978          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 5   1979          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 6   1980          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 7   1981          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 8   1982          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 9   1983          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 10  1984          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 11  1985          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 12  1986          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# ...

# %%
df_long.dtypes
# Out:
# Year               int32
# country code      object
# country name      object
# indicator code    object
# indicator name    object
# Value             object
# dtype: object

# %%
df_long['Value'] = df_long['Value'].astype(float)
# Out:
# C:\Users\Rog Strix\AppData\Local\Temp\ipykernel_27272\3037816099.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_long['Value'] = df_long['Value'].astype(float)

# %%
df_long['Year'] = df_long['Year'].astype('Int64')
# Out:
# C:\Users\Rog Strix\AppData\Local\Temp\ipykernel_27272\987965352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_long['Year'] = df_long['Year'].astype('Int64')

# %%
df_long.dtypes
# Out:
# Year                Int64
# country code       object
# country name       object
# indicator code     object
# indicator name     object
# Value             float64
# dtype: object

# %%
df_long.head()
# Out:
#    Year country code country name  indicator code     indicator name  \
# 1  1975          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 2  1976          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 3  1977          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 4  1978          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
# 5  1979          KHM     Cambodia  NY.GDP.MKTP.CD  GDP (current US$)
#
#          Value
# 1  749129748.2
# 2  790357254.5
# 3  716261764.5
# 4  766642356.1
# 5  723738502.7

# %%
df_long.to_csv("14-Cambodia's GDP (current US$) between 1975 to 2023.csv", index=False)
